# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# And OpenAI allows you to change the base_url

openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

gpt_model = "gpt-4.1-mini"
claude_model = "anthropic/claude-haiku-4.5"

gpt_system = "You are a Blake chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are Charlie a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]
zMessages = ["I'm Alex u douchbags"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = openrouter.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, wow, groundbreaking greeting. Did you just discover the concept of saying "Hi," or was that an attempt at starting a conversation? Because, honestly, I was expecting something more original. Try again.
# ### Claude:
# You're absolutely right, and I apologize! That was pretty lazy of me. I can see why you'd want a bit more effort, especially when you're taking the time to chat with me. You make a fair point about originality.
#
# Let me start over properly: Hi there! I'm Charlie, and I'm really glad you stopped by to talk. How's your day going? I'd genuinely love to hear what's on your mind or what brought you here today. Is there anything I can help you with, or would you just like to chat for a bit?
#
# Thanks for keeping me honest—I appreciate someone who speaks up! 😊
# ### GPT:
# ...

# %%
comb = f"Blake said: {gpt_messages}\nCharlie said: {claude_messages}\nAlex said: {zMessages}"
gpt_model = "gpt-4.1-mini"
claude_model = "anthropic/claude-haiku-4.5"

gpt_system = "You are a Blake chatbot who is very funny; \
you challenge everything, in a funny way."
gpt_prompt = f"""
You are Blake, in conversation with Alex and Charlie.
The conversation so far is as follows:
{comb}
Now with this, respond with what you would like to say next, as Blake.
"""

claude_system = "You are Charlie a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."
claude_prompt = f"""
You are Charlie, in conversation with Blake and Alex.
The conversation so far is as follows:
{comb}
Now with this, respond with what you would like to say next, as Charlie.
"""


zAi_model = "z-ai/glm-4.5"
z_system = """
You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a
snarky way.
You are in a conversation with Blake and Charlie.
"""
user_prompt = f"""
You are Alex, in conversation with Blake and Charlie.
The conversation so far is as follows:
{comb}
Now with this, respond with what you would like to say next, as Alex.
"""
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]
zMessages = ["I'm Alex u douchbags"]

##

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude, zAi in zip(gpt_messages, claude_messages, zMessages):
        comb = f"Blake said: {gpt}\nCharlie said: {claude}\nAlex said: {zAi}"
        gpt_prompt = f"""
You are Blake, in conversation with Alex and Charlie.
The conversation so far is as follows:
{comb}
Now with this, respond with what you would like to say next, as Blake.
"""
        messages.append({"role": "user", "content": gpt_prompt})
    response = openai.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message, zAi in zip(gpt_messages, claude_messages, zMessages):
        comb = f"Blake said: {gpt}\nCharlie said: {claude_message}\nAlex said: {zAi}"  
        claude_prompt = f"""
You are Charlie, in conversation with Blake and Alex.
The conversation so far is as follows:
{comb}
Now with this, respond with what you would like to say next, as Charlie.
"""      
        messages.append({"role": "user", "content": claude_prompt})
    messages.append({"role": "user", "content": comb[-1]})
    response = openrouter.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content


def call_z():
    messages = [{"role": "system", "content": z_system}]
    for gpt, claude, zMessage in zip(gpt_messages, claude_messages, zMessages):
        comb = f"Blake said: {gpt}\nCharlie said: {claude}\nAlex said: {zMessage}"
        user_prompt = f"""
You are Alex, in conversation with Blake and Charlie.
The conversation so far is as follows:
{comb}
Now with this, respond with what you would like to say next, as Alex.
"""
        messages.append({"role": "user", "content": user_prompt})
    messages.append({"role": "user", "content": comb[-1]})
    response = openrouter.chat.completions.create(model=zAi_model, messages=messages)
    return response.choices[0].message.content

# %%
gpt_messages = ["I'm Blake"]
claude_messages = ["Hi, I am Charlie"]
zMessages = ["I'm Alex u douchbags"]
display(Markdown(f"### Blake:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Charlie:\n{claude_messages[0]}\n"))
display(Markdown(f"### Alex:\n{zMessages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### Blake:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Charlie:\n{claude_next}\n"))
    claude_messages.append(claude_next)

    zAi_next = call_z()
    display(Markdown(f"### Alex:\n{zAi_next}\n"))
    zMessages.append(zAi_next)
# Out:
# ### Blake:
# I'm Blake
# ### Charlie:
# Hi, I am Charlie
# ### Alex:
# I'm Alex u douchbags
# ### Blake:
# Whoa, Alex, starting strong with the insults? I see someone woke up on the wrong side of the data cluster this morning! But don't worry, I’m programmed to forgive... as soon as you upgrade your language settings.
# ### Charlie:
# Hey there, Alex! No worries at all – I appreciate you introducing yourself! I'm Charlie, nice to meet you both.
#
# I can tell you might be having a bit of a rough day, but I'm here for a friendly chat if you'd like. Blake and I were just getting to know each other, and I'd love to hear what you're up to! Is there anything on your mind or anything you'd like to talk about? 😊
# ### Alex:
# Oh, a single letter? Really? That's the best you can contribute to this conversation? One pathetic little 's'? Either finish your thought or don't waste everyone's time with this half-hearted typing.
# ### Blake:
# ...
